# %% [markdown]
# # Librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import pingouin as pg
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
# Cambiar el nombre de las variables de el data set de 2013 - el nombre de las columnas es distinto al de 2018 por lo que se unifica
# y se modifica en el fichero original, por lo que sólo hay que hacer este proceso una vez
#df13 = pd.read_csv('Files/esudb13p.csv', sep = ',')
#df13.rename(columns = {'PW010':'PW010T','PW030':'PW030T','PW050':'PW050T','PW060': 'PW060T','PW070':'PW070T',
#                        'PW080':'PW080T','PW090':'PW090T','PW100':'PW100T','PW120':'PW120T','PW160': 'PW160T',
#                        'PW190':'PW190T'}, inplace = True)
#df13.to_csv('Files/esudb13p.csv', sep = ',',index = False)
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3058: DtypeWarning: Columns (11,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # Funciones para lectura y concatenado

# %%
# Función para generar strings con nombres de los ficheros cambiando el identificador del año 
def filelist(st1,st2,n1,n2):
    filelist = []
    for n in range(n1,n2):
        if n < 10:
            filename = st1 + '0' + str(n) + st2
            filelist.append(filename)
        else: 
            filename = st1 + str(n) + st2
            filelist.append(filename)
    return filelist

# %%
# Función para concatenar los ficheros de los distintos años en un sólo fichero
def concatenated_df(df_list):
    df_temp = pd.DataFrame()
    for file in df_list:
        df = pd.read_csv(file)
        if df_temp.shape == (0,0):
            df_temp = df
        else: 
            df_temp = pd.concat([df_temp,df])
    return df_temp

# %%
# Listas con los ficheros de cada tipo que contienen datos de todos los años
d_filelist = filelist('Files/esudb','d.csv',4,19) # Ficheros información geográfica año 2004 - 2018
h_filelist = filelist('Files/esudb','h.csv',4,19) # Ficheros información del hogar año 2004 - 2018
p_filelist = filelist('Files/esudb','p.csv',4,19) # Ficheros información de la persona año 2004 - 2018

# %%
# %%time
df_D = concatenated_df(d_filelist)
# Out:
# CPU times: user 609 ms, sys: 453 ms, total: 1.06 s
# Wall time: 1.06 s

# %%
# %%time
df_H = concatenated_df(h_filelist)
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (49,75,79,89) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (101) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (3,9,73,79,95,97,99,101,111,113,123) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (7,9,13,15,17,19,21,23,51,77,85,87,89,95,97,99,101,103,105,109,111,113,115,117,121,123,125,127,133,142,144,145,146,148,150,152,154,156,158,160,162,166,172,176) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (3,13,79,99,103,119,133,146,152,158,188) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (87,99,103,111,119,131,133,135,154,164) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (13,101,109,111,113,115,121,125,133,137,142) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (13,21,85,87,91,93,95,99,105,117,121,135,142) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (9,89,103,105,121,133,142,152,156,158,160,162) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (3,103,105,121,133,142,148) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (85,95,97,99,101,121,133,142,148) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (3,13,81,87,89,95,97,101,103,105,117,121,123,127,133,148) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (9,13,89,95,99,105,109,111,113,115,119,121,125,133,145,151) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (99,103,105,109,111,113,115,121,123,125,133) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (9,13,21,85,87,89,91,99,103,105,127,145) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# CPU times: user 1min 2s, sys: 14.6 s, total: 1min 17s
# Wall time: 1min 17s

# %%
# %%time
df_P = concatenated_df(p_filelist)
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (31,39,43,57,59,61,63,65,67,99,101,103,105,107,109,111,113,115,121,125) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (9,23,31,43,57,59,61,63,65,67,91,93,95,97,99,101,103,105,107,109,111,113,115,121,125) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (5,23,31,39,43,57,59,61,63,65,67,91,93,95,97,99,115) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (11,23,25,31,39,43,97,99,101,115,117,119,121,125) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (11) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (11,39) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (39) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/IPython/core/magic.py:187: DtypeWarning: Columns (11,226) have mixed types.Specify dtype option on import or set low_memory=False.
#   call = lambda f, *a, **k: f(*a, **k)
# CPU times: user 3min 16s, sys: 48.2 s, total: 4min 4s
# Wall time: 4min 8s

# %% [markdown]
# # Limpieza y selección de variables fichero D / Sociodemográficos
#
#
# ### Diccionario de variables seleccionadas y códigos asociados:
#
# | Variable    | Descripción  |  Categoría   | Código  |
# | ----------- | -------------| -------------| --------|
# | **DB010**    | **Año** | - |-|
# | **DB030**    | **Identificación del hogar** | - |-|
# | **DB040**    | **Región** | Galicia |ES11|
# | | |Principado de Asturias | ES12 |
# | | |Cantabria   | ES13 |
# | | |País Vasco  | ES21 |
# | | |Comunidad Foral de Navarra | ES22 |
# | | |La Rioja    | ES23 |
# | | |Aragón      | ES24 |
# | | |Comunidad de Madrid    | ES30 |
# | | |Castilla y León      | ES24 |
# | | |Comunidad de Madrid | 	ES30 |
# | | |Castilla y León | ES41 |
# | | |Castilla-La Mancha	| ES42 |
# | | |Extremadura | ES43 |
# | | |Cataluña | ES51 |
# | | |Comunidad Valenciana | ES52 |
# | | |Illes Balears | ES53 |
# | | |Andalucía | ES61 |
# | | |Región de Murcia | ES62 |
# | | |Ciudad Autónoma de Ceuta | ES63 |
# | | |Ciudad Autónoma de Melilla | ES64 |
# | | |Canarias | ES70 |
# | | |Extra-Regio | ESZZ |
# | **DB100** | **Habitat** | Grande | 1	|
# | | |Mediano| 2 |
# | | |Pequeño| 3 |

# %%
print(df_D.shape)
df_D.head()
# Out:
# (196498, 11)
#    DB010 DB020  DB030 DB040  DB040_F DB060  DB060_F       DB090  DB090_F  \
# 0   2004    ES      1  ES21        1     1        1   997.96215        1
# 1   2004    ES      2  ES21        1     1        1  1001.89779        1
# 2   2004    ES      3  ES21        1     1        1  1105.30224        1
# 3   2004    ES      4  ES21        1     1        1   319.55250        1
# 4   2004    ES      5  ES21        1     1        1  2817.80555        1
#
#    DB100  DB100_F
# 0      3        1
# 1      3        1
# 2      3        1
# 3      3        1
# 4      3        1

# %%
# %%time

# Selección de variables
dfD_varlist = ['DB010','DB030','DB040','DB100']

# Filtrado de columnas 
df_D1 = df_D[dfD_varlist]

# Cambio de nombre de las variables
df_D1.rename(columns = {'DB030':'HHId','DB010': 'Year','DB040': 'Region',\
                             'DB100': 'Habitat'}, inplace = True)

# Creación de un ID año + ID del hogar para evitar duplicaciones entre los ids de distintos años
df_D1['Year_HHid'] = df_D1['Year'].astype(str) + '_' + df_D1['HHId'].astype(str)

# Cambio de códigos de CCAA por definición de la categoría

df_D1['Region'] = df_D1['Region'].map({'ES11':'Galicia','ES12':'Principado de Asturias','ES13':'Cantabria','ES21':'País Vasco',
                     'ES22':'Comunidad Foral de Navarra','ES23':'La Rioja','ES24':'Aragón','ES30':'Comunidad de Madrid',
                     'ES24':'Castilla y León','ES30':'Comunidad de Madrid','ES41':'Castilla y León','ES42':'Castilla-La Mancha',
                     'ES43':'Extremadura','ES51':'Cataluña','ES52':'Comunidad Valenciana','ES53':'Illes Balears',
                     'ES61':'Andalucía','ES62':'Región de Murcia','ES63':'Ciudad Autónoma de Ceuta',
                     'ES64':'Ciudad Autónoma de Melilla','ES70':'Canarias','ESZZ':'Extra-Regio'})


# Cambio de códigos para el tamaño del hábitat por definición de la categoría
df_D1['Habitat']= df_D1['Habitat'].map({1: 'Big', 2 : 'Medium', 3 : 'Small' }) 

# Tamaño del dataframe una vez aplicados los cambios
print(df_D1.shape)
df_D1.head()
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# (196498, 5)
# CPU times: user 859 ms, sys: 219 ms, total: 1.08 s
# Wall time: 1.16 s
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#    Year  HHId      Region Habitat Year_HHid
# 0  2004     1  País Vasco   Small    2004_1
# 1  2004     2  País Vasco   Small    2004_2
# 2  2004     3  País Vasco   Small    2004_3
# 3  2004     4  País Vasco   Small    2004_4
# 4  2004     5  País Vasco   Small    2004_5

# %% [markdown]
# # Limpieza y selección de variables fichero H / Datos del hogar
#
#
# ### Diccionario de variables seleccionadas y códigos asociados:
#
# | Variable    | Descripción  |  Categoría   | Código  |
# | ----------- | -------------| -------------| --------|
# | **HB010**    | **Año** | - |-|
# | **HB030**    | **Identificación del hogar** | - | - |
# | **HB040**    | **Posibilidad de irse de vacaciones anualmente** |Sí | 1 |
# | | |No | 2 |
# | **HS050**    | **Posibilidad de comer alimentos cárnicos dos veces por semana** |Sí | 1 |
# | | |No | 2 |
# | **HS060**    | **Fondo de reserva económico** |Sí | 1 |
# | | |No | 2 |
# | **HS070**    | **Disponibilidad de teléfono en el hogar** |Sí | 1 |
# | | |No | 2 |
# | **HS080**    | **Disponibilidad de televisión en el hogar** |Sí | 1 |
# | | |No | 2 |
# | **HS090**    | **Disponibilidad de ordenador en el hogar** |Sí | 1 |
# | | |No | 2 |
# | **HS100**    | **Disponibilidad de lavadora en el hogar** |Sí | 1 |
# | | |No | 2 |
# | **HS110**    | **Disponibilidad de coche en el hogar** |Sí | 1 |
# | | |No | 2 |
# | **HS120**    | **Capacidad para llegar a fin de mes** |Sí | 1 |
# | | |No | 2 |
# | **HS140**    | **Impacto de los gastos del hogar** |Sí | 1 |
# | | |No | 2 |
# | **HH050**    | **Capacidad de poner / calentar la casa en invierno** |Sí | 1 |
# | | |No | 2 |
# | **HX040**    | **Número de miembros del hogar** | - |-|
# | **HX240**    | **Número de unidades de consumo** | - |-|
# | **vhRentaa**    | **Renta** | - |-|
# | **vhRentaAIa**    | **Renta** | - |-|
# | **vhPobreza**    | **Hogar bajo el umbral de la pobreza** | - |-|
# | **vhMATDEP**    | **Hogar en carencia material severa** | - |-|

# %%
# %%time

# Selección de variables
dfH_varlist = ['HB010','HB030','HS040','HS050','HS060','HS070','HS080','HS090','HS100','HS110',
               'HS120', 'HS140','HH050','HX040','HX240','vhRentaa','vhRentaAIa','vhPobreza','vhMATDEP']

# Filtrado de columnas 
df_H1  = df_H[dfH_varlist]

# Cambio de nombre de las variables
df_H1.rename(columns = {'HB010':'Year','HB030': 'HHId', 'HS040':'HHHolidays','HS050':'HHFood', 
                             'HS060':'HHReserves','HS070':'HHPhone', 'HS080':'HHTV','HS090':'HHComputer', 
                             'HS100':'HHWashMachine', 'HS110': 'HHCar','HS120':'AREMonth', 'HS140':'HousingCost',
                             'HH050':'HHHeath', 'HX040':'HHnMembers','HX060':'HHType', 'HX240' : 'HHConsUnits'}, inplace = True)

# Creación de un ID año + ID del hogar para evitar duplicaciones entre los ids de distintos años
df_H1['Year_HHid'] = df_H1['Year'].astype(str) + '_' + df_H1['HHId'].astype(str)

# Función para convertir a float las variable de renta y y otras que deberían ser numéricas
def to_numeric(x):
    if type(x) is str:
        x = x.lstrip()
        if not x:
            return np.NaN
        else:
            return float(x)
    else: 
        return x

# Aplicación de la función to_numeric a renta y dificultad para llegar a fin de mes
df_H1['vhRentaa'] = df_H1['vhRentaa'].apply(to_numeric)
df_H1['vhRentaAIa'] = df_H1['vhRentaAIa'].apply(to_numeric)
df_H1['AREMonth'] = df_H1['AREMonth'].apply(to_numeric)

df_H1['vhPobreza'] =  df_H1['vhPobreza'].apply(lambda x: 'vhPobreza_Yes' if (x == '1' or x == 1) \
                                                              else 'vhPobreza_No' if (x == '0' or x == 0) else 'Unknown / Not Declared')

df_H1['vhMATDEP'] =  df_H1['vhMATDEP'].apply(lambda x: 'vhMATDEP_Yes' if x == 1 \
                                                              else 'vhMATDEP_No')

df_H1['HousingCost'] = df_H1['HousingCost'].apply(lambda x: 'HighImpactHH' if (x == '1' or x == 1)\
                                                            else 'MediumImpactHH' if (x == '2' or x == 2) \
                                                            else 'LowImpactHH' if (x == '3' or x == 3) \
                                                            else 'Unknown / Not Declared')

# Función para sustituir los valores de privación marterial
def HHDepriv(x):
    if x == '1' or x == 1:
        return 'Yes'
    elif x == '2' or x == 2:
        return 'No'
    elif x == '3' or x == 3:
        return 'No_otros'
    else:
        return 'Unknown / Not Declared'

# Lista de variables de privación material   

list_depriv = ['HHFood','HHHolidays','HHReserves','HHPhone','HHTV','HHComputer',
              'HHWashMachine','HHCar','HHHeath']
    
df_H1[list_depriv] = df_H1[list_depriv].applymap(lambda s: HHDepriv(s))    
    

df_H1.tail()
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:36: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 3.48 s, sys: 2.89 s, total: 6.38 s
# Wall time: 6.62 s
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
#        Year   HHId HHHolidays HHFood HHReserves HHPhone HHTV HHComputer  \
# 13363  2018  18507        Yes    Yes        Yes     Yes  Yes        Yes
# 13364  2018  18508        Yes    Yes        Yes     Yes  Yes        Yes
# 13365  2018  18510        Yes    Yes        Yes     Yes  Yes   No_otros
# 13366  2018  18512        Yes    Yes        Yes     Yes  Yes        Yes
# 13367  2018  18513        Yes    Yes         No     Yes  Yes   No_otros
#
#       HHWashMachine HHCar  AREMonth     HousingCost HHHeath  HHnMembers  \
# 13363           Yes   Yes       3.0    HighImpactHH     Yes           4
# 13364           Yes   Yes       3.0  MediumImpactHH     Yes           7
# 13365           Yes   Yes       3.0  MediumImpactHH     Yes           3
# 13366           Yes   Yes       4.0  MediumImpactHH     Yes           5
# 13367           Yes    No       2.0    HighImpactHH     Yes           5
#
#        HHConsUnits  vhRentaa  vhRentaAIa      vhPobreza     vhMATDEP  \
# 13363          2.5  51597.60    57887.56   vhPobreza_No  vhMATDEP_No
# 13364          3.8  72297.00    78837.63   vhPobreza_No  vhMATDEP_No
# 13365          2.0  40182.60    44813.90   vhPobreza_No  vhMATDEP_No
# 13366          2.8  71015.40    77682.03   vhPobreza_No  vhMATDEP_No
# 13367          2.8  14925.59    14925.59  vhPobreza_Yes  vhMATDEP_No
#
#         Year_HHid
# 13363  2018_18507
# 13364  2018_18508
# 13365  2018_18510
# 13366  2018_18512
# 13367  2018_18513

# %%
df_H1.groupby('vhPobreza')['HHFood'].count()
# Out:
# vhPobreza
# Unknown / Not Declared       844
# vhPobreza_No              156188
# vhPobreza_Yes              39466
# Name: HHFood, dtype: int64

# %% [markdown]
# # Fusión de las variables de dfH y dfD

# %%
dfHH = df_H1.merge(df_D1, left_on = ['Year_HHid','Year','HHId'], right_on = ['Year_HHid','Year','HHId'], how = 'outer')
print(dfHH.shape)
dfHH.head()
# Out:
# (196498, 22)
#    Year  HHId HHHolidays HHFood HHReserves   HHPhone HHTV HHComputer  \
# 0  2004     1        Yes    Yes        Yes       Yes  Yes        Yes
# 1  2004     2         No    Yes        Yes       Yes  Yes   No_otros
# 2  2004     3        Yes    Yes        Yes       Yes  Yes   No_otros
# 3  2004     4        Yes    Yes        Yes       Yes  Yes   No_otros
# 4  2004     5        Yes    Yes        Yes  No_otros  Yes   No_otros
#
#   HHWashMachine     HHCar  AREMonth     HousingCost HHHeath  HHnMembers  \
# 0           Yes       Yes       4.0  MediumImpactHH     Yes           3
# 1           Yes  No_otros       2.0    HighImpactHH     Yes           1
# 2           Yes       Yes       4.0  MediumImpactHH     Yes           2
# 3           Yes       Yes       4.0  MediumImpactHH     Yes           2
# 4           Yes  No_otros       5.0  MediumImpactHH     Yes           1
#
#    HHConsUnits  vhRentaa  vhRentaAIa      vhPobreza     vhMATDEP Year_HHid  \
# 0          1.8   40821.0    44829.02   vhPobreza_No  vhMATDEP_No    2004_1
# 1          1.0    5068.0     7665.90  vhPobreza_Yes  vhMATDEP_No    2004_2
# 2          1.3   23040.0    25637.90   vhPobreza_No  vhMATDEP_No    2004_3
# 3          1.5   20020.0    23545.62   vhPobreza_No  vhMATDEP_No    2004_4
# 4          1.0    7510.0    10938.46   vhPobreza_No  vhMATDEP_No    2004_5
#
#        Region Habitat
# 0  País Vasco   Small
# 1  País Vasco   Small
# 2  País Vasco   Small
# 3  País Vasco   Small
# 4  País Vasco   Small

# %% [markdown]
# # Limpieza y selección de variables fichero P / Datos de la persona
#
#
# ### Diccionario de variables seleccionadas y códigos asociados:
#
#
# | Variable    | Descripción  |  Categoría   | Código  |
# | ----------- | -------------| -------------| --------|
# | **PB010**   | **Año** | - |-|
# | **PB030**   | **ID del Individuo** | - |-|
# | **PPB150**  | **Sexo** |Hombre | 1 |
# |  |  | Mujer | 2 |
# | **PPB140**  | **Año de nacimiento** | - |-|
# | **PB190**  | **Estado Civil** | Soltero/a |1|
# |  |  | Casado/a | 2 |
# |  |  | Separado/a | 3 |
# |  |  | Viudo/a | 4 |
# |  |  | Divorciado/a | 5 |
# | **PL031**  | **Estado Laboral** | Asalariado a tiempo completo | 1 |
# |  |  | Asalariado a tiempo parcial | 2 |
# |  |  | Trabajador por cuenta propia a tiempo completo | 3 |
# |  |  | Trabajador por cuenta propia a tiempo parcial | 4 |
# |  |  | Parado | 5 |
# |  |  | Estudiante, escolar o en formación | 6 |
# |  |  | Jubilado, retirado, jubilado anticipado o ha cerrado un negocio | 7 |
# |  |  | Incapacitado permanente para trabaja | 8 |
# |  |  | Servicio militar obligatorio o prestación social sustitutoria | 9 |
# |  |  | Dedicado a las labores del hogar, al cuidado de niños u otras personas | 10 |
# |  |  | Otra clase de inactividad económica | 11 |
# | **PE040**  | **Nivel máximo de estudios finalizados** | Menos que primaria |000|
# |  |  | Educación primaria | 100 |
# |  |  | Primera etapa de Educación Secundaria | 200 |
# |  |  | Segunda etapa de Educación Secundaria | 300 |
# |  |  | Orientación general 	344 | 344 |
# |  |  | Orientación profesional (sin acceso directo a educación superior) | 353 |
# |  |  | Orientación profesional (con acceso directo a educación superior) | 354 |
# |  |  | Educación postsecundaria no superior | 400 |
# |  |  | Orientación profesional | 450 |
# |  |  | Educación superior | 500 |
# | **PH010**  | **Valoración estado de salud** | Muy buena  | 1 |
# |  |  | Buena | 2 |
# |  |  | Normal | 3 |
# |  |  | Mala | 4 |
# |  |  | Muy mala | 4 |
# | **PH020**  | **Enfermedades crónicas** | Sí | 1 |
# |  |  | No | 2 |
# | **PH030**  | **Limitaciones en la vida díaria últimos 6 meses** | Seriamente limitado | 1 |
# |  |  | Limitado, pero no seriamente | 2 |
# |  |  | No limitado | 3 |
# | **PD020**  | **Posibilidad de comprar ropa** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PD030**  | **Posibilidad de comprar zapatos** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PD050**  | **Posibilidad de salir y reunirse con amigos** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PD060**  | **Posibilidad de realizar actividades de ocio** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PD070**  | **Posibilidad de gastar dinero en lo que a uno le gusta** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PD080**  | **Posibilidad de tener conexión a internet** | Sí |1|
# |  |  | No, porque no me lo puedo permitir | 2 |
# |  |  | No, por otras razones | 3 |
# | **PW050T** | **Frecuencia se ha sentido tenso** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW050T** | **Frecuencia se ha sentido tenso** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW060T** | **Frecuencia se ha sentido bajo de moral** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW070T** | **Frecuencia se ha sentido calmado** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW080T** | **Frecuencia se ha sentido deprimido** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW090T** | **Frecuencia se ha sentido feliz** | Siempre |1|
# |  |  | Frecuentemente | 2 |
# |  |  | Algunas veces | 3 |
# |  |  | Casi nunca | 3 |
# |  |  | Nunca | 3 |
# | **PW010T** | **Satisfacción con la vida** | - |-|
# | **PW030** | **Satisfacción con las relaciones personales** | - |-|
# | **PW120T** | **Satisfacción con el tiempo que dedica a sí mismo** | - |-|
# | **PW160T** | **Satisfacción con su economía** | - |-|

# %%
# %%time
dfP_varlist = ['PB010', 'PB030','PB150','PB140','PB190','PL031','PE040','PH010','PH020','PH030', 
               'PD020','PD030','PD050','PD060','PD070','PD080', 'PW050T','PW060T','PW070T','PW080T','PW090T',
               'PW010T','PW030T','PW120T','PW160T']

df_P1 = df_P[dfP_varlist]

df_P1.rename(columns = {'PB010':'Year','PB030':'IndID','PB150':'Sex','PB140':'YBirht','PB190':'MarStatus',
                       'PL031': 'WorStatus', 'PE040':'FStudies','PH010':'CHealth',
                       'PH020':'CrConditions','PH030':'HLimitations', 'PD020':'MDClothes','PD030':'MDShoes', 'PD050':'MDFriends',
                       'PD060':'MDLeisure', 'PD070':'MDSelf','PD080':'MDInternet',                  
                       'PW050T':'FFTense','PW060T':'FFDown','PW070T':'FFCalm','PW080T':'FFDepressed','PW090T':'FFHappy',
                       'PW010T':'WSOovsat','PW030T':'WBSrelations','PW120T':'WBSowntime','PW160T':'WSBeconomy'}, 
                        inplace = True)

# Household Id
# El identificador del individuo lleva asociado el código del hogar. El identificador del individuo son los dos últimos dígitos
# de el Id del individuo y el resto es el Id de su hogar
df_P1['HHId'] = df_P1['IndID'].apply(lambda x: str(x)[:-2]).astype(int)

# Generamos un código único por individuo y año y repetimos la operación por hogar, aunque en el caso del hogar los IDs estarán
# repetidos para las personas que conformen la misma unidad
df_P1['Year_HHid'] = df_P1['Year'].astype(str) + '_'+ df_P1['HHId'].astype(str)
df_P1['Year_IndID'] = df_P1['Year'].astype(str) + '_'+ df_P1['IndID'].astype(str)

# Conversión variable género
df_P1['Sex'] = df_P1['Sex'].apply(lambda x: 'Hombre' if x == 1 else 'Mujer')

# Conversión año de nacimiento en edad
df_P1['AgeNumeric'] = df_P1['Year'] - df_P1['YBirht']

# Convertimos la variable de condiciones de salud en numérica, que si bien es categórica es ordinal 
df_P1['CHealth'] = df_P1['CHealth'].apply(to_numeric)

# Conversión variable género
df_P1['CrConditions'] = df_P1['CrConditions'].apply(lambda x: 'NChronic' if x == '2'\
                                                              else 'YChronic' if x == '1' else 'Unknown / Not Declared')

# Conversión variable género
df_P1['HLimitations'] = df_P1['HLimitations'].apply(lambda x: 'SerLimited' if x == '1'\
                                                              else 'NoSerLimitedG_limitado' if x == '2' \
                                                              else 'NoLimited' if x == '3' else 'Unknown / Not declared')


# Lista de variables de felicidad  
list_happines = ['FFTense','FFDown','FFCalm','FFDepressed','FFHappy','WSOovsat','WBSrelations','WBSowntime','WSBeconomy']
    
df_P1[list_happines] = df_P1[list_happines].applymap(lambda s: to_numeric(s)) 


# Marital status
def civilstate(x):
    if x == '1': 
        return 'Soltero'
    elif x == '2':
        return 'Casado'
    elif x == '3': 
        return 'Separado'
    elif x == '4': 
        return 'Viudo'
    elif x == '5':
        return 'Divorciado'
    else:
        return 'Uknown / Prefer not to say'

# Conversión variable estado civil
df_P1['MarStatus'] = df_P1['MarStatus'].apply(civilstate)    
    
# Studies
def studiesF(x):
    if x == '000': 
        return '<Primaria'
    elif x == '100':
        return 'Primaria'
    elif x == '200': 
        return 'Secundaria1'
    elif x == '300': 
        return 'Secundaria2'
    elif x == '344':
        return 'OrGeneral'
    elif x == '353' or x == '354':
        return 'OrProfesional'
    elif x == '400':
        return 'SecundariaNoOb'
    elif x == '450':
        return 'OrProfesional'
    elif x == '500':
        return 'EdSuperior'
    else:
        return 'Uknown'
    
# Conversión variable estudios
df_P1['FStudies'] = df_P1['FStudies'].apply(studiesF)    
    
# Workign Status
def workingStatus(x):
    if x == '1': 
        return 'EmployeeFT'
    elif x == '2':
        return 'EmployeePT'
    elif x == '3': 
        return 'SEmployedFT'
    elif x == '4': 
        return 'SEmployedPT'
    elif x == '5':
        return 'Unemployed'
    elif x == '6':
        return 'Student'
    elif x == '7':
        return 'Retired'
    elif x == '9':
        return 'NotAble'
    elif x == '10':
        return 'HHoldKeeper'
    elif x == '11':
        return 'OtherNonWorking'
    else:
        return 'Uknown / Not declared'    

# Conversión estatus del laboral
df_P1['WorStatus'] = df_P1['WorStatus'].apply(workingStatus)


# Privación material personal
def MatDepriv(x):
    if x == '1':
        return 'Yes'
    elif x == '2':
        return 'No affordable'
    elif x == '3': 
        return 'No, other reason'
    else:
        return 'Unknown / Not Declared'

    
list_pdepriv = ['MDClothes','MDShoes','MDFriends','MDLeisure','MDSelf','MDInternet']
    
df_P1[list_pdepriv] = df_P1[list_pdepriv].applymap(lambda s: MatDepriv(s)) 


df_P1.tail()
# Out:
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:4133: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:35: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py:2963: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self[k1] = value[k2]
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:66: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:92: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /home/mariacarrasco/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:120: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# CPU times: user 13.4 s, sys: 12.7 s, total: 26.1 s
# Wall time: 26.8 s
#        Year    IndID     Sex  YBirht MarStatus   WorStatus     FStudies  \
# 28367  2018  1851202   Mujer    1971    Casado  EmployeeFT   EdSuperior
# 28368  2018  1851203  Hombre    2001   Soltero     Student  Secundaria1
# 28369  2018  1851301   Mujer    1973     Viudo  EmployeePT  Secundaria1
# 28370  2018  1851302   Mujer    1998   Soltero  Unemployed  Secundaria1
# 28371  2018  1851303  Hombre    1999   Soltero  Unemployed    OrGeneral
#
#        CHealth CrConditions HLimitations MDClothes MDShoes MDFriends  \
# 28367      1.0     NChronic    NoLimited       Yes     Yes       Yes
# 28368      1.0     NChronic    NoLimited       Yes     Yes       Yes
# 28369      2.0     NChronic    NoLimited       Yes     Yes       Yes
# 28370      1.0     NChronic    NoLimited       Yes     Yes       Yes
# 28371      1.0     NChronic    NoLimited       Yes     Yes       Yes
#
#               MDLeisure         MDSelf MDInternet  FFTense  FFDown  FFCalm  \
# 28367               Yes            Yes        Yes      5.0     5.0     1.0
# 28368               Yes            Yes        Yes      5.0     5.0     1.0
# 28369  No, other reason  No affordable        Yes      4.0     4.0     2.0
# 28370  No, other reason            Yes        Yes      5.0     5.0     1.0
# 28371               Yes            Yes        Yes      5.0     5.0     1.0
#
#        FFDepressed  FFHappy  WSOovsat  WBSrelations  WBSowntime  WSBeconomy  \
# 28367          5.0      1.0      10.0          10.0         8.0        10.0
# 28368          5.0      1.0      10.0          10.0        10.0        10.0
# 28369          4.0      1.0       8.0           5.0         5.0        10.0
# 28370          5.0      1.0       8.0           5.0         8.0        10.0
# 28371          5.0      1.0       8.0           5.0         8.0        10.0
#
#         HHId   Year_HHid    Year_IndID  AgeNumeric
# 28367  18512  2018_18512  2018_1851202          47
# 28368  18512  2018_18512  2018_1851203          17
# 28369  18513  2018_18513  2018_1851301          45
# 28370  18513  2018_18513  2018_1851302          20
# 28371  18513  2018_18513  2018_1851303          19

# %% [markdown]
# # Fusión de las variables de dfHH y df_P1:
# #### Datos de la persona y datos del hogar

# %%
dfFinal = dfHH.merge(df_P1, left_on = ['Year_HHid','Year','HHId'], right_on = ['Year_HHid','Year','HHId'], how = 'outer')
print(dfFinal.shape)
dfFinal.head()
# Out:
# (436818, 48)
#    Year  HHId HHHolidays HHFood HHReserves HHPhone HHTV HHComputer  \
# 0  2004     1        Yes    Yes        Yes     Yes  Yes        Yes
# 1  2004     1        Yes    Yes        Yes     Yes  Yes        Yes
# 2  2004     2         No    Yes        Yes     Yes  Yes   No_otros
# 3  2004     3        Yes    Yes        Yes     Yes  Yes   No_otros
# 4  2004     4        Yes    Yes        Yes     Yes  Yes   No_otros
#
#   HHWashMachine     HHCar  AREMonth     HousingCost HHHeath  HHnMembers  \
# 0           Yes       Yes       4.0  MediumImpactHH     Yes           3
# 1           Yes       Yes       4.0  MediumImpactHH     Yes           3
# 2           Yes  No_otros       2.0    HighImpactHH     Yes           1
# 3           Yes       Yes       4.0  MediumImpactHH     Yes           2
# 4           Yes       Yes       4.0  MediumImpactHH     Yes           2
#
#    HHConsUnits  vhRentaa  vhRentaAIa      vhPobreza     vhMATDEP Year_HHid  \
# 0          1.8   40821.0    44829.02   vhPobreza_No  vhMATDEP_No    2004_1
# 1          1.8   40821.0    44829.02   vhPobreza_No  vhMATDEP_No    2004_1
# 2          1.0    5068.0     7665.90  vhPobreza_Yes  vhMATDEP_No    2004_2
# 3          1.3   23040.0    25637.90   vhPobreza_No  vhMATDEP_No    2004_3
# 4          1.5   20020.0    23545.62   vhPobreza_No  vhMATDEP_No    2004_4
#
#        Region Habitat  IndID     Sex  YBirht   MarStatus  \
# 0  País Vasco   Small    101  Hombre    1964      Casado
# 1  País Vasco   Small    102   Mujer    1967      Casado
# 2  País Vasco   Small    201   Mujer    1941       Viudo
# 3  País Vasco   Small    301   Mujer    1964  Divorciado
# 4  País Vasco   Small    401  Hombre    1944      Casado
#
#                WorStatus FStudies  CHealth CrConditions  \
# 0  Uknown / Not declared   Uknown      2.0     NChronic
# 1  Uknown / Not declared   Uknown      2.0     NChronic
# 2  Uknown / Not declared   Uknown      4.0     YChronic
# 3  Uknown / Not declared   Uknown      2.0     NChronic
# 4  Uknown / Not declared   Uknown      3.0     YChronic
#
#              HLimitations               MDClothes                 MDShoes  \
# 0               NoLimited  Unknown / Not Declared  Unknown / Not Declared
# 1               NoLimited  Unknown / Not Declared  Unknown / Not Declared
# 2               NoLimited  Unknown / Not Declared  Unknown / Not Declared
# 3  NoSerLimitedG_limitado  Unknown / Not Declared  Unknown / Not Declared
# 4               NoLimited  Unknown / Not Declared  Unknown / Not Declared
#
#                 MDFriends               MDLeisure                  MDSelf  \
# 0  Unknown / Not Declared  Unknown / Not Declared  Unknown / Not Declared
# 1  Unknown / Not Declared  Unknown / Not Declared  Unknown / Not Declared
# 2  Unknown / Not Declared  Unknown / Not Declared  Unknown / Not Declared
# 3  Unknown / Not Declared  Unknown / Not Declared  Unknown / Not Declared
# 4  Unknown / Not Declared  Unknown / Not Declared  Unknown / Not Declared
#
#                MDInternet  FFTense  FFDown  FFCalm  FFDepressed  FFHappy  \
# 0  Unknown / Not Declared      NaN     NaN     NaN          NaN      NaN
# 1  Unknown / Not Declared      NaN     NaN     NaN          NaN      NaN
# 2  Unknown / Not Declared      NaN     NaN     NaN          NaN      NaN
# 3  Unknown / Not Declared      NaN     NaN     NaN          NaN      NaN
# 4  Unknown / Not Declared      NaN     NaN     NaN          NaN      NaN
#
#    WSOovsat  WBSrelations  WBSowntime  WSBeconomy Year_IndID  AgeNumeric
# 0       NaN           NaN         NaN         NaN   2004_101          40
# 1       NaN           NaN         NaN         NaN   2004_102          37
# 2       NaN           NaN         NaN         NaN   2004_201          63
# 3       NaN           NaN         NaN         NaN   2004_301          40
# 4       NaN           NaN         NaN         NaN   2004_401          60

# %% [markdown]
# # Recodificar variables dummies

# %%
dummyList = ['Year','IndID','HHHolidays','HHFood','HHReserves','HHPhone','HHTV','HHComputer','HHWashMachine', \
             'HHCar','HousingCost','HHHeath','vhPobreza','vhMATDEP','Sex','MarStatus','WorStatus','FStudies', \
             'CrConditions','HLimitations','MDClothes','MDShoes','MDFriends','MDLeisure','MDSelf','MDInternet']

dfFinal_dummies = pd.get_dummies(dfFinal[dummyList])

dfFinal = dfFinal.merge(dfFinal_dummies, left_on =['Year','IndID'], right_on = ['Year','IndID'])

# %%
dfFinal2 = dfFinal[(dfFinal['Year'] == 2018) | (dfFinal['Year'] == 2013)]

# %%
dfFinal2['vhPobreza_vhPobreza_Yes'].unique()
# Out:
# array([0, 1], dtype=uint8)

# %%
dfFinal2.corr()
# Out:
#                                           Year      HHId  AREMonth  \
# Year                                  1.000000  0.170816  0.151583
# HHId                                  0.170816  1.000000  0.034218
# AREMonth                              0.151583  0.034218  1.000000
# HHnMembers                           -0.055733 -0.012970 -0.128064
# HHConsUnits                          -0.057446 -0.007474 -0.122687
# vhRentaa                              0.043296  0.011046  0.364349
# vhRentaAIa                            0.057149  0.015373  0.378255
# IndID                                 0.170816  1.000000  0.034218
# YBirht                                0.085986  0.011611 -0.073678
# CHealth                              -0.028406 -0.017196 -0.139038
# FFTense                               0.152105  0.040170  0.187009
# FFDown                               -0.011372  0.001792  0.238177
# FFCalm                               -0.106729 -0.034489 -0.184456
# FFDepressed                           0.077796  0.013162  0.260670
# FFHappy                              -0.088355 -0.040382 -0.203616
# WSOovsat                              0.118219  0.026827  0.316117
# WBSrelations                          0.126542  0.032140  0.599970
# WBSowntime                            0.065148  0.023962  0.154846
# WSBeconomy                            0.133669  0.032513  0.163736
# AgeNumeric                            0.048236  0.011324  0.094245
# HHHolidays_No                        -0.133036 -0.025979 -0.599395
# HHHolidays_Unknown / Not Declared     0.004141  0.002924 -0.003765
# HHHolidays_Yes                        0.132999  0.025954  0.599424
# HHFood_No                            -0.003061  0.020814 -0.199179
# WorStatus_SEmployedPT                 0.004196 -0.007364  0.000404
# WorStatus_Student                     0.017180 -0.038787 -0.010507
# WorStatus_Uknown / Not declared      -0.334524  0.351784 -0.075679
# WorStatus_Unemployed                 -0.021747 -0.074960 -0.214247
# FStudies_<Primaria                    0.199434  0.027458 -0.045675
# FStudies_EdSuperior                   0.399604  0.072476  0.215043
# FStudies_OrGeneral                    0.158262  0.029487  0.015336
# FStudies_OrProfesional                0.099115  0.020254 -0.004053
# FStudies_Primaria                     0.290017  0.030518 -0.001543
# FStudies_Secundaria1                  0.378856  0.071760 -0.028083
# FStudies_Secundaria2                  0.277929  0.059892  0.062808
# FStudies_SecundariaNoOb               0.024854 -0.002036  0.001275
# FStudies_Uknown                      -0.992352 -0.171909 -0.150602
# CrConditions_NChronic                -0.015885 -0.008402  0.077785
# CrConditions_Unknown / Not Declared  -0.042989  0.006622 -0.020002
# CrConditions_YChronic                 0.025935  0.006945 -0.073826
# HLimitations_NoLimited                0.052612 -0.000980  0.118944
# HLimitations_NoSerLimitedG_limitado  -0.030640  0.001887 -0.083647
# HLimitations_SerLimited              -0.027695 -0.004523 -0.076261
# HLimitations_Unknown / Not declared  -0.043266  0.006269 -0.019601
# MDClothes_No affordable              -0.042102  0.009461 -0.357310
# MDClothes_No, other reason           -0.123931 -0.054981 -0.069495
# MDClothes_Unknown / Not Declared     -0.082508  0.008360 -0.028951
# MDClothes_Yes                         0.126361  0.014885  0.342971
# MDShoes_No affordable                 0.010951  0.000150 -0.186502
# MDShoes_No, other reason             -0.030729 -0.019314 -0.035039
# MDShoes_Unknown / Not Declared       -0.083172  0.008139 -0.029048
# MDShoes_Yes                           0.056054  0.000379  0.162135
# MDFriends_No affordable               0.028242  0.012675 -0.318000
# MDFriends_No, other reason           -0.060807 -0.039688 -0.057127
# MDFriends_Unknown / Not Declared     -0.083662  0.008376 -0.028603
# MDFriends_Yes                         0.051553  0.016014  0.278593
# MDLeisure_No affordable               0.002750  0.006476 -0.384467
# MDLeisure_No, other reason           -0.137349 -0.067549 -0.042638
# MDLeisure_Unknown / Not Declared     -0.083858  0.007984 -0.028813
# MDLeisure_Yes                         0.140551  0.051920  0.313630
# MDSelf_No affordable                 -0.030461  0.004622 -0.401190
# MDSelf_No, other reason              -0.114026 -0.053647 -0.017372
# MDSelf_Unknown / Not Declared        -0.083172  0.008195 -0.029048
# MDSelf_Yes                            0.129984  0.032086  0.335362
# MDInternet_No affordable             -0.059054 -0.000236 -0.290317
# MDInternet_No, other reason          -0.131493 -0.025388 -0.028398
# MDInternet_Unknown / Not Declared    -0.083073  0.008560 -0.029700
# MDInternet_Yes                        0.172861  0.019401  0.201618
#
#                                       HHnMembers  HHConsUnits  vhRentaa  \
# Year                                   -0.055733    -0.057446  0.043296
# HHId                                   -0.012970    -0.007474  0.011046
# AREMonth                               -0.128064    -0.122687  0.364349
# HHnMembers                              1.000000     0.978557  0.286607
# HHConsUnits                             0.978557     1.000000  0.308159
# vhRentaa                                0.286607     0.308159  1.000000
# MDLeisure_No, other reason             -0.108789    -0.104088 -0.132472
# MDLeisure_Unknown / Not Declared        0.056613     0.067113  0.029222
# MDLeisure_Yes                           0.041011     0.043100  0.258721
# MDSelf_No affordable                    0.045734     0.033572 -0.227328
# MDSelf_No, other reason                -0.041684    -0.037440 -0.065953
# MDSelf_Unknown / Not Declared           0.055927     0.066336  0.027546
# MDSelf_Yes                             -0.022975    -0.019594  0.216726
# MDInternet_No affordable                0.033703     0.024004 -0.184058
# MDInternet_No, other reason            -0.266405    -0.255500 -0.203063
# MDInternet_Unknown / Not Declared       0.056663     0.067004  0.027567
# MDInternet_Yes                          0.192755     0.185817  0.273128
#
#                                       vhRentaAIa     IndID    YBirht  \
# Year                                    0.057149  0.170816  0.085986
# HHId                                    0.015373  1.000000  0.011611
# AREMonth                                0.378255  0.034218 -0.073678
# HHnMembers                              0.275320 -0.012969  0.394247
# HHConsUnits                             0.298515 -0.007474  0.372002
# vhRentaa                                0.995653  0.011046  0.108519
# vhRentaAIa                              1.000000  0.015373  0.093956
# IndID                                   0.015373  1.000000  0.011611
# YBirht                                  0.093956  0.011611  1.000000
# CHealth                                -0.160434 -0.017197 -0.495933
# FFTense                                 0.065092  0.040170  0.018877
# FFDown                                  0.152087  0.001792  0.135745
# FFCalm                                 -0.075233 -0.034489 -0.049817
# FFDepressed                             0.166378  0.013162  0.150228
# FFHappy                                -0.126920 -0.040382 -0.164063
# WSOovsat                                0.208100  0.026827  0.164989
# WBSrelations                            0.360746  0.032140  0.048507
# WBSowntime                              0.022812  0.023962 -0.100286
# WSBeconomy                              0.089479  0.032513  0.079592
# AgeNumeric                             -0.086512  0.011323 -0.990989
# HHHolidays_No                          -0.341014 -0.025979  0.004981
# HHHolidays_Unknown / Not Declared      -0.002657  0.002924 -0.006790
# HHHolidays_Yes                          0.341034  0.025954 -0.004922
# HHFood_No                              -0.105622  0.020814  0.012313
# HHFood_Unknown / Not Declared          -0.002657  0.002924 -0.006790
# HHFood_Yes                              0.105658 -0.020879 -0.012146
# HHReserves_No                          -0.345372 -0.003665  0.056115
# HHReserves_Unknown / Not Declared      -0.002657  0.002924 -0.006790
# HHReserves_Yes                          0.345392  0.003639 -0.056054
# HHPhone_No                             -0.039041  0.010249 -0.001342
# HHPhone_No_otros                       -0.050433  0.001485 -0.047807
# HHPhone_Unknown / Not Declared         -0.006964  0.010492  0.007073
# HHPhone_Yes                             0.063905 -0.007735  0.040479
# HHTV_No                                -0.030341  0.003726  0.002316
# HHTV_No_otros                          -0.014742 -0.013906  0.013268
# HHTV_Unknown / Not Declared                  NaN       NaN       NaN
# HHTV_Yes                                0.028366  0.009962 -0.012553
# HHComputer_No                          -0.160251 -0.008685  0.055293
# HHComputer_No_otros                    -0.250255  0.000283 -0.440218
# HHComputer_Unknown / Not Declared       0.004308  0.003129 -0.015572
# HHComputer_Yes                          0.313473  0.004142  0.376845
# HHWashMachine_No                       -0.040392  0.001026  0.005649
# HHWashMachine_No_otros                 -0.034973 -0.008714 -0.030660
# HHWashMachine_Unknown / Not Declared         NaN       NaN       NaN
# HHWashMachine_Yes                       0.053148  0.005720  0.018742
# HHCar_No                               -0.159305  0.003949  0.062397
# HHCar_No_otros                         -0.211106 -0.015067 -0.331799
# HHCar_Unknown / Not Declared           -0.006384 -0.009149 -0.007118
# HHCar_Yes                               0.274221  0.011218  0.255865
# HousingCost_HighImpactHH               -0.217252 -0.011290  0.037493
# HousingCost_LowImpactHH                 0.048319  0.006110 -0.032024
# HousingCost_MediumImpactHH              0.200791  0.009352 -0.026088
# HousingCost_Unknown / Not Declared      0.007452 -0.010553  0.002193
# HHHeath_No                             -0.156803  0.011977  0.025125
# HHHeath_Unknown / Not Declared         -0.002657  0.002924 -0.006790
# HHHeath_Yes                             0.156828 -0.012021 -0.025018
# vhPobreza_Unknown / Not Declared             NaN       NaN       NaN
# vhPobreza_vhPobreza_No                  0.438594  0.005980 -0.095015
# vhPobreza_vhPobreza_Yes                -0.438594 -0.005980  0.095015
# vhMATDEP_vhMATDEP_No                    0.160934 -0.011240 -0.062784
# vhMATDEP_vhMATDEP_Yes                  -0.160934  0.011240  0.062784
# Sex_Hombre                              0.035869 -0.004494  0.051332
# Sex_Mujer                              -0.035869  0.004494 -0.051332
# MarStatus_Casado                        0.107128 -0.001046 -0.289584
# MarStatus_Divorciado                   -0.074253  0.003998 -0.015237
# MarStatus_Separado                     -0.058207  0.000124 -0.023920
# MarStatus_Soltero                      -0.001981 -0.001345  0.571164
# MarStatus_Uknown / Prefer not to say    0.028384  0.007314  0.039301
# MarStatus_Viudo                        -0.119351 -0.001605 -0.409733
# WorStatus_EmployeeFT                    0.213113 -0.078003  0.235704
# WorStatus_EmployeePT                   -0.023774 -0.032522  0.114025
# WorStatus_HHoldKeeper                  -0.113152 -0.053887 -0.257298
# WorStatus_OtherNonWorking              -0.030126 -0.021943 -0.043688
# WorStatus_Retired                      -0.034537 -0.048509 -0.534603
# WorStatus_SEmployedFT                   0.029294 -0.039408  0.038493
# WorStatus_SEmployedPT                  -0.003901 -0.007364  0.011362
# WorStatus_Student                       0.062036 -0.038787  0.429248
# WorStatus_Uknown / Not declared        -0.053441  0.351784 -0.035823
# WorStatus_Unemployed                   -0.132153 -0.074960  0.164336
# FStudies_<Primaria                     -0.097444  0.027458 -0.201521
# FStudies_EdSuperior                     0.234706  0.072476  0.143070
# FStudies_OrGeneral                      0.039832  0.029488  0.262470
# FStudies_OrProfesional                 -0.001820  0.020254  0.144541
# FStudies_Primaria                      -0.093365  0.030517 -0.202636
# FStudies_Secundaria1                   -0.067931  0.071760  0.096014
# FStudies_Secundaria2                    0.024416  0.059892 -0.010786
# FStudies_SecundariaNoOb                 0.001021 -0.002036 -0.000944
# FStudies_Uknown                        -0.054776 -0.171909 -0.081835
# CrConditions_NChronic                   0.092610 -0.008402  0.389797
# CrConditions_Unknown / Not Declared     0.028697  0.006622  0.039558
# CrConditions_YChronic                  -0.100010  0.006945 -0.402204
# HLimitations_NoLimited                  0.119034 -0.000980  0.372131
# MDLeisure_No affordable               0.140671 -0.149797 -0.206631  0.137620
# MDLeisure_No, other reason            0.286482 -0.058324 -0.107426  0.066361
# MDLeisure_Unknown / Not Declared      0.010188 -0.003134 -0.006285  0.006991
# MDLeisure_Yes                        -0.351623  0.157406  0.240900 -0.155981
# MDSelf_No affordable                  0.145636 -0.163617 -0.219071  0.150522
# MDSelf_No, other reason               0.200154 -0.048002 -0.079582  0.053814
# MDSelf_Unknown / Not Declared         0.009871 -0.002925 -0.005197  0.005549
# MDSelf_Yes                           -0.262262  0.166335  0.233891 -0.160129
# MDInternet_No affordable              0.114920 -0.098969 -0.153890  0.088149
# MDInternet_No, other reason           0.306538  0.002729 -0.090738  0.036335
# MDInternet_Unknown / Not Declared     0.010195 -0.004543 -0.003859  0.006016
# MDInternet_Yes                       -0.338021  0.056519  0.171663 -0.084643
#
#                                       FFDepressed   FFHappy  WSOovsat  \
# Year                                     0.077796 -0.088355  0.118219
# HHId                                     0.013162 -0.040382  0.026827
# AREMonth                                 0.260670 -0.203616  0.316117
# HHnMembers                               0.072805 -0.098874  0.057770
# HHConsUnits                              0.070751 -0.093235  0.048624
# vhRentaa                                 0.164655 -0.126247  0.205197
# vhRentaAIa                               0.166378 -0.126920  0.208100
# IndID                                    0.013162 -0.040382  0.026827
# YBirht                                   0.150228 -0.164063  0.164989
# CHealth                                 -0.362836  0.330591 -0.396893
# FFTense                                  0.563381 -0.430396  0.328068
# FFDown                                   0.769617 -0.518785  0.444967
# FFCalm                                  -0.498140  0.531714 -0.322908
# FFDepressed                              1.000000 -0.547806  0.467601
# FFHappy                                 -0.547806  1.000000 -0.473877
# WSOovsat                                 0.467601 -0.473877  1.000000
# WBSrelations                             0.364824 -0.332741  0.585192
# WBSowntime                               0.202262 -0.222284  0.326903
# WSBeconomy                               0.280173 -0.342298  0.493107
# AgeNumeric                              -0.140166  0.152612 -0.149495
# HHHolidays_No                           -0.235380  0.186651 -0.304670
# HHHolidays_Unknown / Not Declared             NaN       NaN       NaN
# HHHolidays_Yes                           0.235380 -0.186651  0.304670
# HHFood_No                               -0.105400  0.080296 -0.137840
# HHFood_Unknown / Not Declared                 NaN       NaN       NaN
# HHFood_Yes                               0.105400 -0.080296  0.137840
# HHReserves_No                           -0.219258  0.156703 -0.252771
# HHReserves_Unknown / Not Declared             NaN       NaN       NaN
# HHReserves_Yes                           0.219258 -0.156703  0.252771
# HHPhone_No                              -0.028627  0.022189 -0.042872
# HHPhone_No_otros                        -0.019027  0.022498 -0.036669
# HHPhone_Unknown / Not Declared           0.006893  0.010360  0.003397
# HHPhone_Yes                              0.030071 -0.031657  0.052793
# HHTV_No                                 -0.023676  0.024092 -0.046739
# HHTV_No_otros                            0.008691  0.005291  0.007332
# HHTV_Unknown / Not Declared                   NaN       NaN       NaN
# HHTV_Yes                                 0.005128 -0.017230  0.018474
# HHComputer_No                           -0.109254  0.083432 -0.134064
# HHComputer_No_otros                     -0.122248  0.106323 -0.141801
# HHComputer_Unknown / Not Declared       -0.008867  0.009617 -0.011175
# HHComputer_Yes                           0.169575 -0.141533  0.200493
# HHWashMachine_No                        -0.039325  0.034370 -0.047509
# HHWashMachine_No_otros                  -0.008659  0.009599 -0.019665
# HHWashMachine_Unknown / Not Declared          NaN       NaN       NaN
# HHWashMachine_Yes                        0.032938 -0.030326  0.046642
# HHCar_No                                -0.096711  0.089174 -0.119713
# HHCar_No_otros                          -0.119268  0.117905 -0.122803
# HHCar_Unknown / Not Declared            -0.003918  0.004178 -0.013923
# HHCar_Yes                                0.158604 -0.153208  0.174747
# HousingCost_HighImpactHH                -0.180037  0.138266 -0.198228
# HousingCost_LowImpactHH                  0.035627 -0.030499  0.042389
# HousingCost_MediumImpactHH               0.168220 -0.128160  0.184174
# HousingCost_Unknown / Not Declared      -0.006924  0.010972 -0.012834
# HHHeath_No                              -0.151749  0.124563 -0.176007
# HHHeath_Unknown / Not Declared                NaN       NaN       NaN
# HHHeath_Yes                              0.151749 -0.124563  0.176007
# vhPobreza_Unknown / Not Declared              NaN       NaN       NaN
# vhPobreza_vhPobreza_No                   0.117401 -0.072532  0.151491
# vhPobreza_vhPobreza_Yes                 -0.117401  0.072532 -0.151491
# vhMATDEP_vhMATDEP_No                     0.148665 -0.118994  0.179936
# vhMATDEP_vhMATDEP_Yes                   -0.148665  0.118994 -0.179936
# Sex_Hombre                               0.106439 -0.053852  0.015579
# Sex_Mujer                               -0.106439  0.053852 -0.015579
# MarStatus_Casado                         0.034219 -0.064454  0.065623
# MarStatus_Divorciado                    -0.059005  0.067954 -0.062160
# MarStatus_Separado                      -0.052423  0.051027 -0.055944
# MarStatus_Soltero                        0.081417 -0.055247  0.041427
# MarStatus_Uknown / Prefer not to say    -0.004169  0.003711 -0.002581
# MarStatus_Viudo                         -0.126663  0.132118 -0.113458
# WorStatus_EmployeeFT                     0.136671 -0.095833  0.157413
# WorStatus_EmployeePT                     0.011412 -0.011097  0.012032
# WorStatus_HHoldKeeper                   -0.084509  0.054034 -0.049288
# WorStatus_OtherNonWorking               -0.024764  0.034003 -0.039048
# WorStatus_Retired                       -0.006449  0.028608 -0.030828
# WorStatus_SEmployedFT                    0.034498 -0.014381  0.031775
# WorStatus_SEmployedPT                   -0.003112  0.000021  0.007237
# WorStatus_Student                        0.100348 -0.093777  0.110633
# WorStatus_Uknown / Not declared         -0.078617  0.045752 -0.071951
# WorStatus_Unemployed                    -0.116981  0.075829 -0.161798
# FStudies_<Primaria                      -0.071720  0.068457 -0.083856
# FStudies_EdSuperior                      0.116731 -0.100296  0.147039
# FStudies_OrGeneral                       0.064940 -0.069270  0.074272
# FStudies_OrProfesional                   0.036611 -0.039109  0.032562
# FStudies_Primaria                       -0.043341  0.036709 -0.041072
# FStudies_Secundaria1                     0.008731 -0.031375  0.027309
# FStudies_Secundaria2                     0.024589 -0.025038  0.038929
# FStudies_SecundariaNoOb                  0.001212  0.006384 -0.002950
# FStudies_Uknown                         -0.077796  0.088355 -0.118219
# CrConditions_NChronic                    0.240994 -0.220643  0.225608
# CrConditions_Unknown / Not Declared     -0.004169  0.003711 -0.000303
# CrConditions_YChronic                   -0.240959  0.220612 -0.225608
# HLimitations_NoLimited                   0.295715 -0.250357  0.282205
# HLimitations_NoSerLimitedG_limitado     -0.207802  0.174509 -0.169868
# HLimitations_SerLimited                 -0.205512  0.176724 -0.247788
# HLimitations_Unknown / Not declared     -0.004896  0.003768 -0.001840
# MDClothes_No affordable                 -0.226311  0.175104 -0.256237
# MDClothes_No, other reason              -0.075877  0.059357 -0.093202
# MDClothes_Unknown / Not Declared        -0.008480  0.011737 -0.001866
# MDClothes_Yes                            0.239914 -0.186171  0.274803
# MDShoes_No affordable                   -0.129882  0.097161 -0.157574
# MDShoes_No, other reason                -0.040432  0.034986 -0.058513
# MDShoes_Unknown / Not Declared          -0.000507  0.005268  0.001305
# MDShoes_Yes                              0.135257 -0.103482  0.166859
# MDFriends_No affordable                 -0.192130  0.162187 -0.236899
# MDFriends_No, other reason              -0.136080  0.134501 -0.176931
# MDFriends_Unknown / Not Declared        -0.001570  0.006364  0.002271
# MDFriends_Yes                            0.243956 -0.220582  0.307147
# MDLeisure_No affordable                 -0.217727  0.180724 -0.263388
# MDLeisure_No, other reason              -0.120118  0.124813 -0.161260
# MDLeisure_Unknown / Not Declared        -0.007421  0.009232 -0.002892
# MDLeisure_Yes                            0.259944 -0.237946  0.328213
# MDSelf_No affordable                    -0.232875  0.187783 -0.260787
# MDSelf_No, other reason                 -0.093821  0.084517 -0.127221
# MDSelf_Unknown / Not Declared           -0.006540  0.008868 -0.003366
# MDSelf_Yes                               0.255375 -0.212486  0.301890
# MDInternet_No affordable                -0.164165  0.133223 -0.209604
# MDInternet_No, other reason             -0.109506  0.110151 -0.146082
# MDInternet_Unknown / Not Declared       -0.008629  0.009549 -0.006766
# MDInternet_Yes                           0.194515 -0.176769  0.253705
#
#                                       WBSrelations  WBSowntime  WSBeconomy  \
# Year                                      0.126542    0.065148    0.133669
# HHId                                      0.032140    0.023962    0.032513
# AREMonth                                  0.599970    0.154846    0.163736
# HHnMembers                               -0.018756   -0.117850    0.006332
# HHConsUnits                              -0.012361   -0.085943    0.007107
# vhRentaa                                  0.351344    0.015972    0.085315
# vhRentaAIa                                0.360746    0.022812    0.089479
# IndID                                     0.032140    0.023962    0.032513
# YBirht                                    0.048507   -0.100286    0.079592
# CHealth                                  -0.255268   -0.091502   -0.227895
# FFTense                                   0.282165    0.295702    0.211161
# FFDown                                    0.341224    0.206651    0.263187
# FFCalm                                   -0.255874   -0.243475   -0.226338
# FFDepressed                               0.364824    0.202262    0.280173
# FFHappy                                  -0.332741   -0.222284   -0.342298
# WSOovsat                                  0.585192    0.326903    0.493107
# WBSrelations                              1.000000    0.290115    0.317055
# WBSowntime                                0.290115    1.000000    0.374018
# WSBeconomy                                0.317055    0.374018    1.000000
# AgeNumeric                               -0.031549    0.109379   -0.061763
# HHHolidays_No                            -0.502567   -0.130582   -0.165430
# HHHolidays_Unknown / Not Declared              NaN         NaN         NaN
# HHHolidays_Yes                            0.502567    0.130582    0.165430
# HHFood_No                                -0.186647   -0.040808   -0.080337
# HHFood_Unknown / Not Declared                  NaN         NaN         NaN
# HHFood_Yes                                0.186647    0.040808    0.080337
# HHReserves_No                            -0.486926   -0.106333   -0.121007
# HHReserves_Unknown / Not Declared              NaN         NaN         NaN
# HHReserves_Yes                            0.486926    0.106333    0.121007
# HHPhone_No                               -0.066875   -0.013599   -0.036274
# HHPhone_No_otros                         -0.023107   -0.000711   -0.036568
# HHPhone_Unknown / Not Declared            0.007711   -0.003435    0.000926
# HHPhone_Yes                               0.052883    0.007885    0.049629
# HHTV_No                                  -0.055332   -0.009467   -0.035820
# HHTV_No_otros                             0.007295   -0.004920   -0.007758
# HHTV_Unknown / Not Declared                    NaN         NaN         NaN
# HHTV_Yes                                  0.023047    0.009185    0.025526
# HHComputer_No                            -0.230498   -0.064369   -0.075961
# HHComputer_No_otros                      -0.090757    0.084904   -0.064214
# HHComputer_Unknown / Not Declared        -0.003262   -0.000056   -0.004648
# HHComputer_Yes                            0.203163   -0.044834    0.098677
# HHWashMachine_No                         -0.059514   -0.007919   -0.037829
# HHWashMachine_No_otros                   -0.016618    0.009355   -0.008738
# HHWashMachine_Unknown / Not Declared           NaN         NaN         NaN
# HHWashMachine_Yes                         0.052434   -0.001580    0.031979
# ...
# MDSelf_Yes                                              -0.139822
# MDInternet_No affordable                                -0.125120
# MDInternet_No, other reason                              1.000000
# MDInternet_Unknown / Not Declared                       -0.062535
# MDInternet_Yes                                          -0.770189
#
#                                       MDInternet_Unknown / Not Declared  \
# Year                                                          -0.083073
# HHId                                                           0.008560
# AREMonth                                                      -0.029700
# HHnMembers                                                     0.056663
# HHConsUnits                                                    0.067004
# vhRentaa                                                       0.027567
# vhRentaAIa                                                     0.024789
# IndID                                                          0.008560
# YBirht                                                         0.038620
# CHealth                                                        0.010195
# FFTense                                                       -0.004543
# FFDown                                                        -0.003859
# FFCalm                                                         0.006016
# FFDepressed                                                   -0.008629
# FFHappy                                                        0.009549
# WSOovsat                                                      -0.006766
# WBSrelations                                                  -0.009494
# WBSowntime                                                    -0.006765
# WSBeconomy                                                    -0.017986
# AgeNumeric                                                    -0.049887
# HHHolidays_No                                                  0.020133
# HHHolidays_Unknown / Not Declared                             -0.000581
# HHHolidays_Yes                                                -0.020128
# HHFood_No                                                      0.013406
# HHFood_Unknown / Not Declared                                 -0.000581
# HHFood_Yes                                                    -0.013388
# HHReserves_No                                                  0.019936
# HHReserves_Unknown / Not Declared                             -0.000581
# HHReserves_Yes                                                -0.019931
# HHPhone_No                                                     0.019722
# HHPhone_No_otros                                              -0.006801
# HHPhone_Unknown / Not Declared                                -0.001299
# HHPhone_Yes                                                   -0.004401
# HHTV_No                                                       -0.000185
# HHTV_No_otros                                                  0.002963
# HHTV_Unknown / Not Declared                                         NaN
# HHTV_Yes                                                      -0.002439
# HHComputer_No                                                  0.010633
# HHComputer_No_otros                                           -0.017770
# HHComputer_Unknown / Not Declared                             -0.002251
# HHComputer_Yes                                                 0.010902
# HHWashMachine_No                                              -0.003155
# HHWashMachine_No_otros                                        -0.003919
# HHWashMachine_Unknown / Not Declared                                NaN
# HHWashMachine_Yes                                              0.005026
# HHCar_No                                                       0.012385
# HHCar_No_otros                                                -0.010885
# HHCar_Unknown / Not Declared                                  -0.001299
# HHCar_Yes                                                      0.002634
# HousingCost_HighImpactHH                                       0.018037
# HousingCost_LowImpactHH                                       -0.004702
# HousingCost_MediumImpactHH                                    -0.016401
# HousingCost_Unknown / Not Declared                            -0.001423
# HHHeath_No                                                     0.021196
# HHHeath_Unknown / Not Declared                                -0.000581
# HHHeath_Yes                                                   -0.021185
# vhPobreza_Unknown / Not Declared                                    NaN
# vhPobreza_vhPobreza_No                                         0.013128
# vhPobreza_vhPobreza_Yes                                       -0.013128
# vhMATDEP_vhMATDEP_No                                          -0.020078
# vhMATDEP_vhMATDEP_Yes                                          0.020078
# Sex_Hombre                                                     0.015728
# Sex_Mujer                                                     -0.015728
# MarStatus_Casado                                              -0.113968
# MarStatus_Divorciado                                          -0.021686
# MarStatus_Separado                                            -0.013952
# MarStatus_Soltero                                             -0.038278
# MarStatus_Uknown / Prefer not to say                           0.803723
# MarStatus_Viudo                                               -0.025630
# WorStatus_EmployeeFT                                           0.036790
# WorStatus_EmployeePT                                          -0.022876
# WorStatus_HHoldKeeper                                         -0.039506
# WorStatus_OtherNonWorking                                      0.002559
# WorStatus_Retired                                             -0.024190
# WorStatus_SEmployedFT                                         -0.026535
# WorStatus_SEmployedPT                                         -0.005853
# WorStatus_Student                                             -0.017027
# WorStatus_Uknown / Not declared                                0.082529
# WorStatus_Unemployed                                          -0.027023
# FStudies_<Primaria                                            -0.027985
# FStudies_EdSuperior                                           -0.056073
# FStudies_OrGeneral                                            -0.022208
# FStudies_OrProfesional                                        -0.013908
# FStudies_Primaria                                             -0.040696
# FStudies_Secundaria1                                          -0.053162
# FStudies_Secundaria2                                          -0.038999
# FStudies_SecundariaNoOb                                       -0.003488
# FStudies_Uknown                                                0.139248
# CrConditions_NChronic                                         -0.117432
# CrConditions_Unknown / Not Declared                            0.806808
# CrConditions_YChronic                                         -0.067694
# HLimitations_NoLimited                                        -0.160169
# HLimitations_NoSerLimitedG_limitado                           -0.049062
# HLimitations_SerLimited                                       -0.000767
# HLimitations_Unknown / Not declared                            0.805567
# MDClothes_No affordable                                       -0.041795
# MDClothes_No, other reason                                    -0.022699
# MDClothes_Unknown / Not Declared                               0.994457
# MDClothes_Yes                                                 -0.344775
# MDShoes_No affordable                                         -0.019353
# MDShoes_No, other reason                                      -0.008457
# MDShoes_Unknown / Not Declared                                 0.992454
# MDShoes_Yes                                                   -0.634814
# MDFriends_No affordable                                       -0.040763
# MDFriends_No, other reason                                    -0.040868
# MDFriends_Unknown / Not Declared                               0.990972
# MDFriends_Yes                                                 -0.284396
# MDLeisure_No affordable                                       -0.052758
# MDLeisure_No, other reason                                    -0.074825
# MDLeisure_Unknown / Not Declared                               0.990984
# MDLeisure_Yes                                                 -0.172430
# MDSelf_No affordable                                          -0.054557
# MDSelf_No, other reason                                       -0.048960
# MDSelf_Unknown / Not Declared                                  0.994467
# MDSelf_Yes                                                    -0.221267
# MDInternet_No affordable                                      -0.037328
# MDInternet_No, other reason                                   -0.062535
# MDInternet_Unknown / Not Declared                              1.000000
# MDInternet_Yes                                                -0.229779
#
#                                       MDInternet_Yes
# Year                                        0.172861
# HHId                                        0.019401
# AREMonth                                    0.201618
# HHnMembers                                  0.192755
# HHConsUnits                                 0.185817
# vhRentaa                                    0.273128
# vhRentaAIa                                  0.273883
# IndID                                       0.019401
# YBirht                                      0.401183
# CHealth                                    -0.338021
# FFTense                                     0.056519
# FFDown                                      0.171663
# FFCalm                                     -0.084643
# FFDepressed                                 0.194515
# FFHappy                                    -0.176769
# WSOovsat                                    0.253705
# WBSrelations                                0.243175
# WBSowntime                                 -0.032600
# WSBeconomy                                  0.144267
# AgeNumeric                                 -0.378966
# HHHolidays_No                              -0.233719
# HHHolidays_Unknown / Not Declared          -0.007157
# HHHolidays_Yes                              0.233780
# HHFood_No                                  -0.103268
# HHFood_Unknown / Not Declared              -0.007157
# HHFood_Yes                                  0.103412
# HHReserves_No                              -0.196799
# HHReserves_Unknown / Not Declared          -0.007157
# HHReserves_Yes                              0.196860
# HHPhone_No                                 -0.069630
# HHPhone_No_otros                           -0.071049
# HHPhone_Unknown / Not Declared              0.001323
# HHPhone_Yes                                 0.096484
# HHTV_No                                    -0.036089
# HHTV_No_otros                               0.004262
# HHTV_Unknown / Not Declared                      NaN
# HHTV_Yes                                    0.015094
# HHComputer_No                              -0.225257
# HHComputer_No_otros                        -0.576546
# HHComputer_Unknown / Not Declared          -0.027721
# HHComputer_Yes                              0.648708
# HHWashMachine_No                           -0.055660
# HHWashMachine_No_otros                     -0.046872
# HHWashMachine_Unknown / Not Declared             NaN
# HHWashMachine_Yes                           0.072266
# HHCar_No                                   -0.092792
# HHCar_No_otros                             -0.324698
# HHCar_Unknown / Not Declared               -0.011672
# HHCar_Yes                                   0.336619
# HousingCost_HighImpactHH                   -0.122271
# HousingCost_LowImpactHH                     0.007522
# HousingCost_MediumImpactHH                  0.120387
# HousingCost_Unknown / Not Declared         -0.005668
# HHHeath_No                                 -0.127016
# HHHeath_Unknown / Not Declared             -0.007157
# HHHeath_Yes                                 0.127114
# vhPobreza_Unknown / Not Declared                 NaN
# vhPobreza_vhPobreza_No                      0.129533
# vhPobreza_vhPobreza_Yes                    -0.129533
# vhMATDEP_vhMATDEP_No                        0.122618
# vhMATDEP_vhMATDEP_Yes                      -0.122618
# Sex_Hombre                                  0.033235
# Sex_Mujer                                  -0.033235
# MarStatus_Casado                            0.066323
# MarStatus_Divorciado                        0.015501
# MarStatus_Separado                         -0.014086
# MarStatus_Soltero                           0.121714
# MarStatus_Uknown / Prefer not to say       -0.184584
# MarStatus_Viudo                            -0.249052
# WorStatus_EmployeeFT                        0.239316
# WorStatus_EmployeePT                        0.072442
# WorStatus_HHoldKeeper                      -0.159483
# WorStatus_OtherNonWorking                  -0.053666
# WorStatus_Retired                          -0.223607
# WorStatus_SEmployedFT                       0.095156
# WorStatus_SEmployedPT                       0.018006
# WorStatus_Student                           0.128258
# WorStatus_Uknown / Not declared            -0.107207
# WorStatus_Unemployed                       -0.001603
# FStudies_<Primaria                         -0.186246
# FStudies_EdSuperior                         0.218111
# FStudies_OrGeneral                          0.086243
# FStudies_OrProfesional                      0.051533
# FStudies_Primaria                          -0.111686
# FStudies_Secundaria1                        0.096781
# FStudies_Secundaria2                        0.119783
# FStudies_SecundariaNoOb                     0.008719
# FStudies_Uknown                            -0.185741
# CrConditions_NChronic                       0.271326
# CrConditions_Unknown / Not Declared        -0.185294
# CrConditions_YChronic                      -0.230866
# HLimitations_NoLimited                      0.319884
# HLimitations_NoSerLimitedG_limitado        -0.205396
# HLimitations_SerLimited                    -0.173724
# HLimitations_Unknown / Not declared        -0.184822
# MDClothes_No affordable                    -0.171790
# MDClothes_No, other reason                 -0.077268
# MDClothes_Unknown / Not Declared           -0.229431
# MDClothes_Yes                               0.270315
# MDShoes_No affordable                      -0.131528
# MDShoes_No, other reason                   -0.054719
# MDShoes_Unknown / Not Declared             -0.229280
# MDShoes_Yes                                 0.260378
# MDFriends_No affordable                    -0.170223
# MDFriends_No, other reason                 -0.199046
# MDFriends_Unknown / Not Declared           -0.228020
# MDFriends_Yes                               0.341556
# MDLeisure_No affordable                    -0.178935
# MDLeisure_No, other reason                 -0.270447
# MDLeisure_Unknown / Not Declared           -0.228253
# MDLeisure_Yes                               0.423032
# MDSelf_No affordable                       -0.189340
# MDSelf_No, other reason                    -0.180626
# MDSelf_Unknown / Not Declared              -0.228666
# MDSelf_Yes                                  0.345549
# MDInternet_No affordable                   -0.459739
# MDInternet_No, other reason                -0.770189
# MDInternet_Unknown / Not Declared          -0.229779
# MDInternet_Yes                              1.000000

# %% [markdown]
# # Creación de variables para predecir:
# #### Datos de la persona y datos del hogar

# %%
# Test the los datos
pg.cronbach_alpha(data = dfFinal[['WBSrelations','WBSowntime','WSBeconomy','WSOovsat']])
# Out:
# (0.7129341152046728, array([0.712, 0.714]))

# %%
#Lista de pesos de correlación de cada variable de satisfacción con la vida 
correlations = dfFinal[['WBSrelations','WBSowntime','WSBeconomy','WSOovsat']].corr()['WSOovsat'][:-1]

# Indicador 1 - Media aritmética
dfFinal['LifeSatisfaction0'] = (dfFinal['WBSrelations'] + dfFinal['WBSowntime'] \
                         + dfFinal['WSBeconomy'] + dfFinal['WSOovsat']) / 4

# Indicador 2 - Proporción de la correlación con la variable principal - satisfacción con la vida
dfFinal['LifeSatisfaction1'] = dfFinal['WBSrelations'] * correlations[0] + dfFinal['WBSowntime'] * correlations[1] \
                            + dfFinal['WSBeconomy'] * correlations[2] + dfFinal['WSOovsat']

# Indicador 3 - Indicador 2 de 0 a 10
dfFinal['LifeSatisfaction2'] = dfFinal['LifeSatisfaction1']  / [dfFinal['LifeSatisfaction1'].max() / 10]

# Df Final a csv
dfFinal.to_csv('./Files/ECV_2004_2018.csv.gz', sep = ';', index = False, compression="gzip")
